# %%
import numpy as np
import cogni_scan.src.nifti_mri as nifti_mri

# %%
img1 =  np.full((100, 100), 0)
img2 =  np.full((30, 30), 10.)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
params = [
    1085,
    "/home/john/oasis3-scans/OAS31172_MR_d1717/scans/anat2-T1w/resources/NIFTI/files/sub-OAS31172_ses-d1717_T1w.nii.gz",
    1717,
    "OAS31172",
    'oasis3',
    0,
    0,
    {'0': 0, '1': 1, '2': 2},
    [0, 0, 0],
    0.2,
    0.2,
    0.2
]

# %%
scan = nifti_mri.Scan(*params)
# Out:
# 1085 /home/john/oasis3-scans/OAS31172_MR_d1717/scans/anat2-T1w/resources/NIFTI/files/sub-OAS31172_ses-d1717_T1w.nii.gz 1717 OAS31172 {'oasis3'} 0 0 {'0': 0, '1': 1, '2': 2} [0, 0, 0] 0.2 0.2 0.2

# %%
s_img = scan.get_slice(distance_from_center=-0.2, axis=1)

# %%
plt.imshow(s_img)

# %%
s_img.shape
# Out:
# (275, 400)

# %%
l_img.shape
# Out:
# (400, 400)

# %%
l_img =  np.full((400, 400), 0)
x_offset= 0
y_offset=65
l_img[y_offset:y_offset+s_img.shape[0], x_offset:x_offset+s_img.shape[1]] = s_img
plt.imshow(l_img)

# %%
import cv2
s_img = cv2.imread("smaller_image.png")
l_img = cv2.imread("larger_image.jpg")
x_offset=y_offset=50
l_img[y_offset:y_offset+s_img.shape[0], x_offset:x_offset+s_img.shape[1]] = s_img
